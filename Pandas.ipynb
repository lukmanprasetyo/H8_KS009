# %% [markdown]
# ## Belajar Pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\numpy-workshop\lib\site-packages (1.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\envs\numpy-workshop\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\numpy-workshop\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\anaconda3\envs\numpy-workshop\lib\site-packages (from pandas) (1.23.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\numpy-workshop\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\User\anaconda3\envs\numpy-workshop
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.5           |  py310h9128911_0         106 KB
#     ca-certificates-2022.10.11 |       haa95532_0         125 KB
#     numexpr-2.8.3              |  py310hb57aa6b_0         119 KB
#     pandas-1.4.4               |  py310hd77b12b_0         8.7 MB
#     ------------------------------------------------------------
#                                            Total:         9.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   bottleneck         pkgs/main/win-64::bottleneck-1.3.5-py310h9128911_0
#   numexpr            pkgs/main/win-64::numexpr-2.8.3-py310hb57aa6b_0
#   pandas             pkgs/main/win-64::pandas-1.4.4-py310hd77b12b_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2022.07.19-haa95532_0 --> 2022.10.11-haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# pandas-1.4.4         | 8.7 MB    |            |   0%
# pandas-1.4.4         | 8.7 MB    |            |   0%
# pandas-1.4.4         | 8.7 MB    | 1          |   1%
# pandas-1.4.4         | 8.7 MB    | 2          |   3%
# pandas-1.4.4         | 8.7 MB    | 3          |   4%
# pandas-1.4.4         | 8.7 MB    | 5          |   5%
# pandas-1.4.4         | 8.7 MB    | 5          |   6%
# pandas-1.4.4         | 8.7 MB    | 6          |   7%
# pandas-1.4.4         | 8.7 MB    | 8          |   8%
# pandas-1.4.4         | 8.7 MB    | 8          |   8%
# pandas-1.4.4         | 8.7 MB    | 8          |   9%
# pandas-1.4.4         | 8.7 MB    | 9          |   9%
# pandas-1.4.4         | 8.7 MB    | 9          |   9%
# pandas-1.4.4         | 8.7 MB    | 9          |  10%
# pandas-1.4.4         | 8.7 MB    | 9          |  10%
# pandas-1.4.4         | 8.7 MB    | #          |  10%
# pandas-1.4.4         | 8.7 MB    | #          |  10%
# pandas-1.4.4         | 8.7 MB    | #          |  11%
# pandas-1.4.4         | 8.7 MB    | #          |  11%
# pandas-1.4.4         | 8.7 MB    | #1         |  11%
# pandas-1.4.4         | 8.7 MB    | #1         |  11%
# pandas-1.4.4         | 8.7 MB    | #1         |  12%
# pandas-1.4.4         | 8.7 MB    | #2         |  12%
# pandas-1.4.4         | 8.7 MB    | #2         |  12%
# pandas-1.4.4         | 8.7 MB    | #2         |  13%
# pandas-1.4.4         | 8.7 MB    | #3         |  13%
# pandas-1.4.4         | 8.7 MB    | #3         |  14%
# pandas-1.4.4         | 8.7 MB    | #4         |  14%
# pandas-1.4.4         | 8.7 MB    | #4         |  15%
# pandas-1.4.4         | 8.7 MB    | #5         |  16%
# pandas-1.4.4         | 8.7 MB    | #6         |  16%
# pandas-1.4.4         | 8.7 MB    | #7         |  17%
# pandas-1.4.4         | 8.7 MB    | #7         |  18%
# pandas-1.4.4         | 8.7 MB    | #8         |  19%
# pandas-1.4.4         | 8.7 MB    | #9         |  19%
# pandas-1.4.4         | 8.7 MB    | #9         |  20%
# pandas-1.4.4         | 8.7 MB    | #9         |  20%
# pandas-1.4.4         | 8.7 MB    | ##         |  20%
# pandas-1.4.4         | 8.7 MB    | ##         |  21%
# pandas-1.4.4         | 8.7 MB    | ##         |  21%
# pandas-1.4.4         | 8.7 MB    | ##         |  21%
# pandas-1.4.4         | 8.7 MB    | ##1        |  21%
# pandas-1.4.4         | 8.7 MB    | ##1        |  21%
# pandas-1.4.4         | 8.7 MB    | ##1        |  21%
# pandas-1.4.4         | 8.7 MB    | ##1        |  22%
# pandas-1.4.4         | 8.7 MB    | ##1        |  22%
# pandas-1.4.4         | 8.7 MB    | ##1        |  22%
# pandas-1.4.4         | 8.7 MB    | ##2        |  22%
# pandas-1.4.4         | 8.7 MB    | ##2        |  22%
# pandas-1.4.4         | 8.7 MB    | ##2        |  23%
# pandas-1.4.4         | 8.7 MB    | ##2        |  23%
# pandas-1.4.4         | 8.7 MB    | ##2        |  23%
# pandas-1.4.4         | 8.7 MB    | ##3        |  23%
# pandas-1.4.4         | 8.7 MB    | ##3        |  24%
# pandas-1.4.4         | 8.7 MB    | ##3        |  24%
# pandas-1.4.4         | 8.7 MB    | ##4        |  24%
# pandas-1.4.4         | 8.7 MB    | ##5        |  25%
# pandas-1.4.4         | 8.7 MB    | ##6        |  26%
# pandas-1.4.4         | 8.7 MB    | ##6        |  27%
# pandas-1.4.4         | 8.7 MB    | ##7        |  28%
# pandas-1.4.4         | 8.7 MB    | ##8        |  28%
# pandas-1.4.4         | 8.7 MB    | ##8        |  29%
# pandas-1.4.4         | 8.7 MB    | ##9        |  29%
# pandas-1.4.4         | 8.7 MB    | ##9        |  29%
# pandas-1.4.4         | 8.7 MB    | ##9        |  30%
# pandas-1.4.4         | 8.7 MB    | ###        |  30%
# pandas-1.4.4         | 8.7 MB    | ###        |  30%
# pandas-1.4.4         | 8.7 MB    | ###        |  30%
# pandas-1.4.4         | 8.7 MB    | ###        |  31%
# pandas-1.4.4         | 8.7 MB    | ###        |  31%
# pandas-1.4.4         | 8.7 MB    | ###        |  31%
# pandas-1.4.4         | 8.7 MB    | ###1       |  31%
# pandas-1.4.4         | 8.7 MB    | ###1       |  31%
# pandas-1.4.4         | 8.7 MB    | ###1       |  32%
# pandas-1.4.4         | 8.7 MB    | ###1       |  32%
# pandas-1.4.4         | 8.7 MB    | ###2       |  32%
# pandas-1.4.4         | 8.7 MB    | ###2       |  32%
# pandas-1.4.4         | 8.7 MB    | ###2       |  33%
# pandas-1.4.4         | 8.7 MB    | ###3       |  34%
# pandas-1.4.4         | 8.7 MB    | ###4       |  34%
# pandas-1.4.4         | 8.7 MB    | ###5       |  35%
# pandas-1.4.4         | 8.7 MB    | ###5       |  36%
# pandas-1.4.4         | 8.7 MB    | ###6       |  37%
# pandas-1.4.4         | 8.7 MB    | ###7       |  37%
# pandas-1.4.4         | 8.7 MB    | ###7       |  38%
# pandas-1.4.4         | 8.7 MB    | ###8       |  38%
# pandas-1.4.4         | 8.7 MB    | ###8       |  38%
# pandas-1.4.4         | 8.7 MB    | ###8       |  39%
# pandas-1.4.4         | 8.7 MB    | ###8       |  39%
# pandas-1.4.4         | 8.7 MB    | ###8       |  39%
# pandas-1.4.4         | 8.7 MB    | ###9       |  39%
# pandas-1.4.4         | 8.7 MB    | ###9       |  39%
# pandas-1.4.4         | 8.7 MB    | ###9       |  39%
# pandas-1.4.4         | 8.7 MB    | ###9       |  40%
# pandas-1.4.4         | 8.7 MB    | ###9       |  40%
# pandas-1.4.4         | 8.7 MB    | ###9       |  40%
# pandas-1.4.4         | 8.7 MB    | ####       |  40%
# pandas-1.4.4         | 8.7 MB    | ####       |  40%
# pandas-1.4.4         | 8.7 MB    | ####       |  41%
# pandas-1.4.4         | 8.7 MB    | ####       |  41%
# pandas-1.4.4         | 8.7 MB    | ####       |  41%
# pandas-1.4.4         | 8.7 MB    | ####1      |  41%
# pandas-1.4.4         | 8.7 MB    | ####1      |  41%
# pandas-1.4.4         | 8.7 MB    | ####1      |  42%
# pandas-1.4.4         | 8.7 MB    | ####2      |  42%
# pandas-1.4.4         | 8.7 MB    | ####2      |  43%
# pandas-1.4.4         | 8.7 MB    | ####3      |  43%
# pandas-1.4.4         | 8.7 MB    | ####3      |  44%
# pandas-1.4.4         | 8.7 MB    | ####4      |  45%
# pandas-1.4.4         | 8.7 MB    | ####5      |  45%
# pandas-1.4.4         | 8.7 MB    | ####5      |  46%
# pandas-1.4.4         | 8.7 MB    | ####6      |  47%
# pandas-1.4.4         | 8.7 MB    | ####7      |  48%
# pandas-1.4.4         | 8.7 MB    | ####8      |  48%
# pandas-1.4.4         | 8.7 MB    | ####9      |  49%
# pandas-1.4.4         | 8.7 MB    | #####      |  50%
# pandas-1.4.4         | 8.7 MB    | #####      |  51%
# pandas-1.4.4         | 8.7 MB    | #####2     |  52%
# pandas-1.4.4         | 8.7 MB    | #####2     |  53%
# pandas-1.4.4         | 8.7 MB    | #####3     |  53%
# pandas-1.4.4         | 8.7 MB    | #####3     |  54%
# pandas-1.4.4         | 8.7 MB    | #####4     |  54%
# pandas-1.4.4         | 8.7 MB    | #####4     |  54%
# pandas-1.4.4         | 8.7 MB    | #####4     |  55%
# pandas-1.4.4         | 8.7 MB    | #####4     |  55%
# pandas-1.4.4         | 8.7 MB    | #####5     |  55%
# pandas-1.4.4         | 8.7 MB    | #####5     |  55%
# pandas-1.4.4         | 8.7 MB    | #####5     |  55%
# pandas-1.4.4         | 8.7 MB    | #####5     |  56%
# pandas-1.4.4         | 8.7 MB    | #####6     |  56%
# pandas-1.4.4         | 8.7 MB    | #####6     |  56%
# pandas-1.4.4         | 8.7 MB    | #####6     |  57%
# pandas-1.4.4         | 8.7 MB    | #####7     |  57%
# pandas-1.4.4         | 8.7 MB    | #####8     |  58%
# pandas-1.4.4         | 8.7 MB    | #####8     |  58%
# pandas-1.4.4         | 8.7 MB    | #####9     |  59%
# pandas-1.4.4         | 8.7 MB    | ######     |  61%
# pandas-1.4.4         | 8.7 MB    | ######     |  61%
# pandas-1.4.4         | 8.7 MB    | ######1    |  61%
# pandas-1.4.4         | 8.7 MB    | ######1    |  61%
# pandas-1.4.4         | 8.7 MB    | ######1    |  61%
# pandas-1.4.4         | 8.7 MB    | ######1    |  62%
# pandas-1.4.4         | 8.7 MB    | ######1    |  62%
# pandas-1.4.4         | 8.7 MB    | ######1    |  62%
# pandas-1.4.4         | 8.7 MB    | ######2    |  62%
# pandas-1.4.4         | 8.7 MB    | ######2    |  62%
# pandas-1.4.4         | 8.7 MB    | ######2    |  63%
# pandas-1.4.4         | 8.7 MB    | ######2    |  63%
# pandas-1.4.4         | 8.7 MB    | ######2    |  63%
# pandas-1.4.4         | 8.7 MB    | ######3    |  63%
# pandas-1.4.4         | 8.7 MB    | ######3    |  63%
# pandas-1.4.4         | 8.7 MB    | ######3    |  63%
# pandas-1.4.4         | 8.7 MB    | ######3    |  64%
# pandas-1.4.4         | 8.7 MB    | ######3    |  64%
# pandas-1.4.4         | 8.7 MB    | ######3    |  64%
# pandas-1.4.4         | 8.7 MB    | ######4    |  64%
# pandas-1.4.4         | 8.7 MB    | ######4    |  64%
# pandas-1.4.4         | 8.7 MB    | ######4    |  64%
# pandas-1.4.4         | 8.7 MB    | ######4    |  65%
# pandas-1.4.4         | 8.7 MB    | ######5    |  65%
# pandas-1.4.4         | 8.7 MB    | ######5    |  65%
# pandas-1.4.4         | 8.7 MB    | ######5    |  66%
# pandas-1.4.4         | 8.7 MB    | ######6    |  66%
# pandas-1.4.4         | 8.7 MB    | ######6    |  67%
# pandas-1.4.4         | 8.7 MB    | ######7    |  68%
# pandas-1.4.4         | 8.7 MB    | ######8    |  68%
# pandas-1.4.4         | 8.7 MB    | ######9    |  69%
# pandas-1.4.4         | 8.7 MB    | ######9    |  70%
# pandas-1.4.4         | 8.7 MB    | #######    |  71%
# pandas-1.4.4         | 8.7 MB    | #######    |  71%
# pandas-1.4.4         | 8.7 MB    | #######1   |  71%
# pandas-1.4.4         | 8.7 MB    | #######1   |  72%
# pandas-1.4.4         | 8.7 MB    | #######2   |  72%
# pandas-1.4.4         | 8.7 MB    | #######2   |  72%
# pandas-1.4.4         | 8.7 MB    | #######2   |  72%
# pandas-1.4.4         | 8.7 MB    | #######2   |  73%
# pandas-1.4.4         | 8.7 MB    | #######2   |  73%
# pandas-1.4.4         | 8.7 MB    | #######2   |  73%
# pandas-1.4.4         | 8.7 MB    | #######3   |  73%
# pandas-1.4.4         | 8.7 MB    | #######3   |  73%
# pandas-1.4.4         | 8.7 MB    | #######3   |  74%
# pandas-1.4.4         | 8.7 MB    | #######4   |  74%
# pandas-1.4.4         | 8.7 MB    | #######4   |  74%
# pandas-1.4.4         | 8.7 MB    | #######4   |  74%
# pandas-1.4.4         | 8.7 MB    | #######4   |  75%
# pandas-1.4.4         | 8.7 MB    | #######4   |  75%
# pandas-1.4.4         | 8.7 MB    | #######4   |  75%
# pandas-1.4.4         | 8.7 MB    | #######5   |  75%
# pandas-1.4.4         | 8.7 MB    | #######5   |  76%
# pandas-1.4.4         | 8.7 MB    | #######6   |  76%
# pandas-1.4.4         | 8.7 MB    | #######6   |  77%
# pandas-1.4.4         | 8.7 MB    | #######6   |  77%
# pandas-1.4.4         | 8.7 MB    | #######7   |  78%
# pandas-1.4.4         | 8.7 MB    | #######8   |  78%
# pandas-1.4.4         | 8.7 MB    | #######9   |  80%
# pandas-1.4.4         | 8.7 MB    | #######9   |  80%
# pandas-1.4.4         | 8.7 MB    | ########   |  80%
# pandas-1.4.4         | 8.7 MB    | ########   |  81%
# pandas-1.4.4         | 8.7 MB    | ########   |  81%
# pandas-1.4.4         | 8.7 MB    | ########1  |  81%
# pandas-1.4.4         | 8.7 MB    | ########1  |  81%
# pandas-1.4.4         | 8.7 MB    | ########1  |  81%
# pandas-1.4.4         | 8.7 MB    | ########1  |  82%
# pandas-1.4.4         | 8.7 MB    | ########1  |  82%
# pandas-1.4.4         | 8.7 MB    | ########1  |  82%
# pandas-1.4.4         | 8.7 MB    | ########2  |  82%
# pandas-1.4.4         | 8.7 MB    | ########2  |  82%
# pandas-1.4.4         | 8.7 MB    | ########2  |  83%
# pandas-1.4.4         | 8.7 MB    | ########2  |  83%
# pandas-1.4.4         | 8.7 MB    | ########2  |  83%
# pandas-1.4.4         | 8.7 MB    | ########3  |  83%
# pandas-1.4.4         | 8.7 MB    | ########3  |  83%
# pandas-1.4.4         | 8.7 MB    | ########3  |  83%
# pandas-1.4.4         | 8.7 MB    | ########3  |  84%
# pandas-1.4.4         | 8.7 MB    | ########4  |  84%
# pandas-1.4.4         | 8.7 MB    | ########4  |  84%
# pandas-1.4.4         | 8.7 MB    | ########5  |  85%
# pandas-1.4.4         | 8.7 MB    | ########5  |  86%
# pandas-1.4.4         | 8.7 MB    | ########6  |  86%
# pandas-1.4.4         | 8.7 MB    | ########6  |  87%
# pandas-1.4.4         | 8.7 MB    | ########7  |  87%
# pandas-1.4.4         | 8.7 MB    | ########8  |  88%
# pandas-1.4.4         | 8.7 MB    | ########9  |  89%
# pandas-1.4.4         | 8.7 MB    | ########9  |  90%
# pandas-1.4.4         | 8.7 MB    | #########  |  91%
# pandas-1.4.4         | 8.7 MB    | #########1 |  91%
# pandas-1.4.4         | 8.7 MB    | #########2 |  92%
# pandas-1.4.4         | 8.7 MB    | #########3 |  94%
# pandas-1.4.4         | 8.7 MB    | #########4 |  94%
# pandas-1.4.4         | 8.7 MB    | #########4 |  94%
# pandas-1.4.4         | 8.7 MB    | #########4 |  95%
# pandas-1.4.4         | 8.7 MB    | #########4 |  95%
# pandas-1.4.4         | 8.7 MB    | #########4 |  95%
# pandas-1.4.4         | 8.7 MB    | #########5 |  95%
# pandas-1.4.4         | 8.7 MB    | #########5 |  95%
# pandas-1.4.4         | 8.7 MB    | #########5 |  95%
# pandas-1.4.4         | 8.7 MB    | #########5 |  96%
# pandas-1.4.4         | 8.7 MB    | #########5 |  96%
# pandas-1.4.4         | 8.7 MB    | #########6 |  96%
# pandas-1.4.4         | 8.7 MB    | #########6 |  96%
# pandas-1.4.4         | 8.7 MB    | #########6 |  96%
# pandas-1.4.4         | 8.7 MB    | #########6 |  97%
# pandas-1.4.4         | 8.7 MB    | #########6 |  97%
# pandas-1.4.4         | 8.7 MB    | #########6 |  97%
# pandas-1.4.4         | 8.7 MB    | #########7 |  97%
# pandas-1.4.4         | 8.7 MB    | #########7 |  97%
# pandas-1.4.4         | 8.7 MB    | #########7 |  97%
# pandas-1.4.4         | 8.7 MB    | #########7 |  98%
# pandas-1.4.4         | 8.7 MB    | #########7 |  98%
# pandas-1.4.4         | 8.7 MB    | #########8 |  98%
# pandas-1.4.4         | 8.7 MB    | #########8 |  99%
# pandas-1.4.4         | 8.7 MB    | #########9 |  99%
# pandas-1.4.4         | 8.7 MB    | #########9 | 100%
# pandas-1.4.4         | 8.7 MB    | ########## | 100%
#
# ca-certificates-2022 | 125 KB    |            |   0%
# ca-certificates-2022 | 125 KB    | #2         |  13%
# ca-certificates-2022 | 125 KB    | ########9  |  89%
# ca-certificates-2022 | 125 KB    | ########## | 100%
# ca-certificates-2022 | 125 KB    | ########## | 100%
#
# bottleneck-1.3.5     | 106 KB    |            |   0%
# bottleneck-1.3.5     | 106 KB    | ######     |  60%
# bottleneck-1.3.5     | 106 KB    | ########## | 100%
#
# numexpr-2.8.3        | 119 KB    |            |   0%
# numexpr-2.8.3        | 119 KB    | #3         |  13%
# numexpr-2.8.3        | 119 KB    | ########## | 100%
# numexpr-2.8.3        | 119 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 22.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ardhiraka/PFDS_sources/master/nbaallelo.csv')

# %%
len(df)
# Out:
# 126314

# %%
# %matplotlib inline
data = pd.ExcelFile('obes.xls')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#       2 data = pd.ExcelFile('obes.xls')
#
# File ~\anaconda3\envs\numpy-workshop\lib\site-packages\IPython\core\interactiveshell.py:2305, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2303     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2304 with self.builtin_trap:
# -> 2305     result = fn(*args, **kwargs)
#    2306 return result
#
# File ~\anaconda3\envs\numpy-workshop\lib\site-packages\IPython\core\magics\pylab.py:99, in PylabMagics.matplotlib(self, line)
#      97     print("Available matplotlib backends: %s" % backends_list)
#      98 else:
# ---> 99     gui, backend = self.shell.enable_matplotlib(args.gui.lower() if isinstance(args.gui, str) else args.gui)
#     100     self._show_matplotlib_backend(args.gui, backend)
#
# File ~\anaconda3\envs\numpy-workshop\lib\site-packages\IPython\core\interactiveshell.py:3478, in InteractiveShell.enable_matplotlib(self, gui)
#    3457 def enable_matplotlib(self, gui=None):
#    3458     """Enable interactive matplotlib and inline figure support.
#    3459
#    3460     This takes the following steps:
#    (...)
#    3476         display figures inline.
#    3477     """
# -> 3478     from matplotlib_inline.backend_inline import configure_inline_support
#    3480     from IPython.core import pylabtools as pt
#    3481     gui, backend = pt.find_gui_and_backend(gui, self.pylab_gui_select)
#
# File ~\anaconda3\envs\numpy-workshop\lib\site-packages\matplotlib_inline\__init__.py:1, in <module>
# ----> 1 from . import backend_inline, config  # noqa
#       2 __version__ = "0.1.6"
#
# File ~\anaconda3\envs\numpy-workshop\lib\site-packages\matplotlib_inline\backend_inline.py:6, in <module>
#       1 """A matplotlib backend for publishing figures via display_data"""
#       3 # Copyright (c) IPython Development Team.
#       4 # Distributed under the terms of the BSD 3-Clause License.
# ----> 6 import matplotlib
#       7 from matplotlib import colors
#       8 from matplotlib.backends import backend_agg
#
# ModuleNotFoundError: No module named 'matplotlib'
